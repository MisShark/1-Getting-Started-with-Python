# %% [markdown]
# Reading a File from your Google Drive

# %%
import io
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

# replace 1_House_Sales_Data.xlsx with the name of your excel file
df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/1_House_Sales_Data.xlsx')

#type df in the code cell to view the data
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading a file stored locally on your PC

# %%
import io
import pandas as pd
from google.colab import files

#read an excel file located locally on your PC 
from google.colab import files 
uploaded = files.upload ()

# %%
import pandas as pd
import io 

# replace B Example 1 - Data Encoding.xlsx with the name of your excel file 
df = pd.read_excel (io.BytesIO(uploaded['B Example 1 - Data Encoding.xlsx']))
df
