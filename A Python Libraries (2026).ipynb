# %% [markdown]
# # *Getting Started with Python Libraries*

# %% [markdown]
# Python libraries are powerful collections of tools; is a collection of pre-written code,
# often organized into modules and packages, that provides reusable functions and classes for performing specific tasks, thereby simplifying and accelerating the development process.
#
# The Python programming language comes with a variety of built-in functions. Among these are several common functions, including:
#
# * print() which prints expressions out
# * abs() which returns the absolute value of a number
# * int() which converts another data type to an integer
# * len() which returns the length of a sequence or collection
#
# These built-in functions, however, are limited, and we can make use of modules to make more sophisticated programs.
#
#
# A module is a set of code or functions with the.py extension. A library is a collection of related modules or packages. They are used by both programmers and developers. Libraries are used by community members, developers and researchers.

# %%
# Let's try to import a module , math
import math

# %% [markdown]
# Since math is a built-in module, your interpreter should complete the task with no feedback, returning to the prompt. This means you don’t need to do anything to start using the math module.
#
# Let’s run the import statement with a module that you may not have installed, like the 2D plotting library matplotlib:

# %%
import matplotlib

# %% [markdown]
# ## NumPy:
# Numerical computing, array manipulation, and scientific computing.
#
# ## Pandas:
# Data manipulation and analysis, especially with DataFrames.
#
# ## Matplotlib:
# Data visualization, creating static, interactive, and animated visualizations.
#
# ## Seaborn:
# Statistical data visualization, building on Matplotlib for more visually appealing and informative plots.
#
# ## Scikit-learn: sklearn
# Machine learning algorithms, providing tools for classification, regression, clustering, and more.
#
# ## TensorFlow:
# Deep learning framework, used for building and training neural networks.
#
# ## SciPy:
# Scientific computing, containing modules for optimization, integration, and signal processing.
#
# ## PyTorch:
# Another popular deep learning framework, known for its flexibility and dynamic computation graphs
#
# ## Keras:
# High-level API for building and training neural networks, often used as a front-end for TensorFlow or Theano.

# %%
import pandas as pd

# %% [markdown]
# Basic data structures in pandas
# Pandas provides two types of classes for handling data:
#
# 1. Series: a one-dimensional labeled array holding data of any type
# such as integers, strings, Python objects etc.
#
# 2. DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
# let's create a pandas series 
# nan is a blank cell, it is defined in numpy library 

s = pd.Series([1, 3, 5, 0, 6, 8])

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    0
# 4    6
# 5    8
# dtype: int64

# %%
# let's create a pandas series 
# nan is a blank cell, it is defined in numpy library 

s = pd.Series([1, 3, 5, np.nan, 6, 8])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_84444\2328450563.py in <module>
#       2 # nan is a blank cell, it is defined in numpy library
#       3
# ----> 4 s = pd.Series([1, 3, 5, np.nan, 6, 8])
#
# NameError: name 'np' is not defined

# %%
# we need to import the numpy library to execute the code correctly 
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# import the pandas library 
import pandas as pd

# %%
# create a dataframe df 
df = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
# to get the number of rows, number of columns of a df 
df.shape
# Out:
# (4, 6)

# %%
# in a dataframe, the index 0 refers to rows 
df.shape [0]
# Out:
# 4

# %%
# in a dataframe, the index 1 refers to columns 
df.shape [1]
# Out:
# 6

# %%
# to get the different datatypes of different columns 
df.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# An object type is a user-defined composite datatype that encapsulates a data structure along with the functions and procedures needed to manipulate the data. Data object will have memory

# %%
# after uploading the dataset onto your anaconda 3 folder (or the folder of this file) 
# if the file you want to read is in .csv (comma seperated) then use pd.read_csv 
# Import an Excel file using the read_excel () function from the pandas library. 
# Set a column index while reading your data into memory.

data = pd.read_excel ('B Example 1 - Data Encoding.xlsx')
data
# Out:
#    S.N  Country  Hours   Salary House
# 0    0   France   34.0  12000.0    No
# 1    1    Spain   37.0  49000.0   Yes
# 2    2  Germany   20.0  34000.0    No
# 3    3    Spain   58.0  41000.0    No
# 4    4  Germany   40.0  43333.3   Yes
# 5    5   France   45.0  28000.0   Yes
# 6    6    Spain   39.8  51000.0    No
# 7    7   France   28.0  89000.0   Yes
# 8    8  Germany   50.0  53000.0    No
# 9    9   France   47.0  33000.0   Yes

# %%
data.dtypes
# Out:
# S.N          int64
# Country     object
# Hours      float64
# Salary     float64
# House       object
# dtype: object

# %%
column_name = df.columns 
column_name
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
# in bigger datasets, you may want to automatically check if data type 'object' is string 


column_type = column_name.dtype
if column_type == 'object':
    print('The column contains string data')
else:
    print('The column does not contain string data')
# Out:
# The column contains string data

# %% [markdown]
# axis = 1 means columns and axis = 0 means rows
#
# ![image.png](attachment:image.png)

# %%
d = {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
d
# Out:
# {'A': 1.0,
#  'B': Timestamp('2013-01-02 00:00:00'),
#  'C': 0    1.0
#  1    1.0
#  2    1.0
#  3    1.0
#  dtype: float32,
#  'D': array([3, 3, 3, 3]),
#  'E': ['test', 'train', 'test', 'train']
#  Categories (2, object): ['test', 'train'],
#  'F': 'foo'}

# %%
pd.DataFrame (data = d)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df.B
# Out:
# 0   2013-01-02
# 1   2013-01-02
# 2   2013-01-02
# 3   2013-01-02
# Name: B, dtype: datetime64[ns]

# %%
df [A]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_84444\4086650841.py in <module>
# ----> 1 df [A]
#
# NameError: name 'A' is not defined

# %%
df["A"]
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
import pandas as pd
data = pd.read_excel ('B Example 1 - Data Encoding.xlsx')
data

data ['Country']
# Out:
# 0     France
# 1      Spain
# 2    Germany
# 3      Spain
# 4    Germany
# 5     France
# 6      Spain
# 7     France
# 8    Germany
# 9     France
# Name: Country, dtype: object

# %%
type (data ['Country'])
# Out:
# pandas.core.series.Series

# %%
data [['Country']]
# Out:
#    Country
# 0   France
# 1    Spain
# 2  Germany
# 3    Spain
# 4  Germany
# 5   France
# 6    Spain
# 7   France
# 8  Germany
# 9   France

# %%
type (data [['Country']])
# Out:
# pandas.core.frame.DataFrame
