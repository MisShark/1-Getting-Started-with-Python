# %%
# import neccessary libraries 
import pandas as pd 
import numpy as np 
import io

# %%
#read an excel file located locally on your PC 
from google.colab import files 
uploaded = files.upload ()
# Out:
#      <input type="file" id="files-fd47c653-9e1b-4dae-9685-d83b42439a23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd47c653-9e1b-4dae-9685-d83b42439a23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving B Example 1 - Data Encoding.xlsx to B Example 1 - Data Encoding.xlsx

# %%
uploaded
# Out:
# {'B Example 1 - Data Encoding.xlsx': b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00A7\x82\xcfn\x01\x00\x00\x04\x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(
# ...

# %%
df = pd.read_excel (io.BytesIO(uploaded['B Example 1 - Data Encoding.xlsx']))
df
# Out:
#    S.N  Country  Hours   Salary House
# 0    0   France   34.0  12000.0    No
# 1    1    Spain   37.0  49000.0   Yes
# 2    2  Germany   20.0  34000.0    No
# 3    3    Spain   58.0  41000.0    No
# 4    4  Germany   40.0  43333.3   Yes
# 5    5   France   45.0  28000.0   Yes
# 6    6    Spain   39.8  51000.0    No
# 7    7   France   28.0  89000.0   Yes
# 8    8  Germany   50.0  53000.0    No
# 9    9   France   47.0  33000.0   Yes

# %% [markdown]
# # **Reading a file in your google drive**

# %%
# import necessary libraries 
import io
import pandas as pd
from google.colab import drive

# %%
#To read/write data from Google Drive:
#Reference: 
# https://docs.google.com/spreadsheets/d/1BjJcin7bIqW1d-DKqUeHVWBNUPCzAq-b/edit?usp=sharing&ouid=100326668963958764285&rtpof=true&sd=true

drive.mount('/content/drive')

df = pd.read_excel('/content/drive/My Drive/Colab Notebooks/1_House_Sales_Data.xlsx')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...
