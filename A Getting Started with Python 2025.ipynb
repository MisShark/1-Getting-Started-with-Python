# %%
# types of cells in jupyter notebook
# Text Cells: Text cells allow you to write and render Markdown  (esc + M )
# syntax. This is where you can describe and document your workflow.
# Code Cells: Code cells allow you to write and run programming code  (esc + A  or  esc + B)

# %% [markdown]
# # A Getting Started with Python

# %%
print ('Nora')
# Out:
# Nora

# %%
# the below is a mistake , because, Nora, is a text, therefore it needs the two single or double qoutes 
print (Nora)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27540\3584459162.py in <module>
#       1 # the below is a mistake , because, Nora, is a text, therefore it needs the two single or double qoutes
# ----> 2 print (Nora)
#
# NameError: name 'Nora' is not defined

# %%
# here we print a number like a student ID, we define it to be a numeric integer 
print (20253454)
# Out:
# 20253454

# %%
# here we print a number like a student ID, we define it to be a text !  
print ('20253454')
# Out:
# 20253454

# %%
# let's print the student ID after assigning it to a variable, called i 
i = 20253454
print (i)
# Out:
# 20253454

# %%
# let's fetch the type of the variable i at this point by using function, type (arg) 
# arg above refers to argument, which is any variable like i 
# functions are like transitive verbs should take something with it, called argument 

type (i)
# Out:
# int

# %%
# please, be careful, do you observe the difference here 
i = 20253454
print ('i')
# Out:
# i

# %%
# let's assign student ID to i, but as a text data type 
i = '20253454'
print (i)
# Out:
# 20253454

# %%
type (i)
# Out:
# str

# %% [markdown]
# ### Python like any programming language, updates the variable assigned value as you progress

# %%
# whether you surround the string with single or double qoates 
print ("Nora")
# Out:
# Nora

# %%
x= 2

# %%
x
# Out:
# 2

# %%
x=3
x
# Out:
# 3

# %% [markdown]
# # Basic Generic Data Types

# %%
i = 4   # this is an integer type of data   
i       # this is how we call i
# Out:
# 4

# %%
type (i)
# Out:
# int

# %%
i = (7)
type (i)
# Out:
# int

# %%
s = nora
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27540\2084618326.py in <module>
# ----> 1 s = nora
#
# NameError: name 'nora' is not defined

# %%
8
# Out:
# 8

# %%
# to define any variable, as in , T, you need to assign a numerical value to it 
T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27540\2803120700.py in <module>
#       1 # to define any variable, as in , T, you need to assign a numerical value to it
# ----> 2 T
#
# NameError: name 'T' is not defined

# %%
S="Sharkasi"
S
# Out:
# 'Sharkasi'

# %%
f = 3.5 + 0.1
f
# Out:
# 3.6

# %%
type (f)
# Out:
# float

# %%
f = 0.3+ 0.7 
f
# Out:
# 1.0

# %%
type (f)
# Out:
# float

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27540\1691629399.py in <module>
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = 'true' # this is here a string 
type (b)
# Out:
# str

# %%
b = True
type (b)
# Out:
# bool

# %% [markdown]
# # Advanced Data Types with Python  <br>
# ## Python dictionary
# A dictionary in Python is an unordered collection of key-value pairs. Each key must be unique, and it is associated with a specific value. Dictionaries provide a flexible and efficient way to store and retrieve data using meaningful identifiers.
#
# ## Python tuples
# are a type of data structure that is very similar to lists. The main difference between the two is that tuples are immutable, meaning they cannot be changed once they are created. This makes them ideal for storing data that should not be modified, such as database records.
# Tuples are used whenever you want to return multiple results from a function. Since they're immutable, they can be used as keys for a dictionary

# %%
# create a list by using [] 
L = [1, 0.5, "nora"]
L
# Out:
# [1, 0.5, 'nora']

# %%
type (L)
# Out:
# list

# %%
# can I create an empty list ? 
My_list = []

# %%
# answer is yes you can create an empty list 
type (My_list)
# Out:
# list

# %%
# Method 1 to create a dictionary, use functio dict ({})
D = dict ({
    2034094 : "Nora Sharkasi" , 345432 : "Quen",
    3940404 : "Lura Smith"
})

# %%
# calling the dictionary , D, it should show a key-value pairs
D
# Out:
# {2034094: 'Nora Sharkasi', 345432: 'Quen', 3940404: 'Lura Smith'}

# %%
# Method 2 to create a dictionary 
D = dict ([(234555, "Nora"), (34455, "Sara") ])
D
# Out:
# {234555: 'Nora', 34455: 'Sara'}

# %%
# Method 3 to create a dictionary 
D = {2034094 : "Nora Sharkasi" , 345432 : "Quen",
    3940404 : "Lura Smith"
}
D
# Out:
# {2034094: 'Nora Sharkasi', 345432: 'Quen', 3940404: 'Lura Smith'}

# %%
# What is the difference between method 1, 2 and 3 ??? 
# method 1 we used dict ({}) , 
# however in method 2, we used dict ([])
# while in method 3 we used just {}

# %%
# can we embed a dictionary in a list ? 
L = [2, 3.2 , 'nora', {394874 : "Sara", 394875 : "Amal" }, 7 ]
L
# Out:
# [2, 3.2, 'nora', {394874: 'Sara', 394875: 'Amal'}, 7]

# %%
L = [ 2, 3.4 , 'Nora', dict[( 3, 3, 'Nora'), (2,4)]]
L
# Out:
# [2, 3.4, 'Nora', dict[(3, 3, 'Nora'), (2, 4)]]

# %%
type (L)
# Out:
# list

# %%
T = [(3, 2.1, 'Nora')]
type (T)
# Out:
# list

# %%
T = ([(3, 2.1, 'Nora')])
type (T)
# Out:
# list

# %%
# when we define the number 7 as an integer we simply use i = 7 or i = (7)
# however, i = [7] define it as a list, or i = ([7])

i = [7]
type (i)
# Out:
# list

# %%
age = [5,6]
weight = [16,17] 
k = [age,weight]
k
# Out:
# [[5, 6], [16, 17]]

# %%
type (k)
# Out:
# list

# %%
F =[age,weight]
F
# Out:
# [[5, 6], [16, 17]]

# %%
type (F)
# Out:
# list

# %%
W = tuple ([3, 202, 'Nora', (3,5), [3,5]])
type (W)
# Out:
# tuple
